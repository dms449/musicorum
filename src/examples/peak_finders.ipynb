# %% [markdown]
# # Peak Finding methods

# %% [markdown]
# include dependencies and get sample data

# %%
using Plots;
include("../data_sets.jl");
include("../functions.jl");
include("../peak_finder.jl");

# %%
data,fs = get_sample(guitar_file,2)
data = data[20000:80000]
x, y = fft_extra(data, fs)

plot(x/1000, y, title="Frequency Domain", xlabel="khz", ylabel="magnitude")

# %% [markdown]
# ## Peak detection algorithms
#
# * algorithm 1
# * algorithm 2
# * algorithm 3

# %% [markdown]
# ### algorithm 1
